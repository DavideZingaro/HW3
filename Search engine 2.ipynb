# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import os
import csv
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Notebook
# [nltk_data]     HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Notebook
# [nltk_data]     HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize
import os

# %%
os.chdir('C:\\Users\\Notebook HP\\Desktop\\TSV_files')
Folder=os.listdir()
Vocabulary=defaultdict(list)
#j=9998
for j in range(10000):
    #for elem in Folder:
    name='document_{}'.format(j)
    try:
        document=open(str(r'C:\Users\Notebook HP\Desktop\TSV_files\article_{}.tsv'.format(j)),'r+',encoding='utf-8')
    except Exception as e:
        continue
    words=word_tokenize(document.read())
    words
    for w in words:
        Vocabulary[w].append(name)
    #j = j+1

# %%
Vocabulary['disney']
# Out:
# ['document_1298',
#  'document_1298',
#  'document_1602',
#  'document_1602',
#  'document_1697',
#  'document_1697',
#  'document_2281',
#  'document_2563',
#  'document_2870',
#  'document_2870',
#  'document_2892',
#  'document_2892',
#  'document_2892',
#  'document_3027',
#  'document_3027',
#  'document_3027',
#  'document_3056',
#  'document_3124',
#  'document_3124',
#  'document_3124',
#  'document_3199',
#  'document_3234',
#  'document_3234',
#  'document_3234',
#  'document_3276',
#  'document_3276',
#  'document_3522',
#  'document_3522',
#  'document_3537',
#  'document_3537',
#  'document_3537',
#  'document_3537',
#  'document_3608',
#  'document_3608',
#  'document_3608',
#  'document_3608',
#  'document_3608',
#  'document_3622',
#  'document_3829',
#  'document_3906',
#  'document_3906',
#  'document_3906',
#  'document_3906',
#  'document_4174',
#  'document_4306',
#  'document_4306',
#  'document_4440',
#  'document_4440',
#  'document_4440',
#  'document_4440',
#  'document_4440',
#  'document_4440',
#  'document_4440',
#  'document_4684',
#  'document_4751',
#  'document_5053',
#  'document_5053',
#  'document_5053',
#  'document_5098',
#  'document_5236',
#  'document_5236',
#  'document_5236',
#  'document_5265',
#  'document_5265',
#  'document_5265',
#  'document_5423',
#  'document_5423',
#  'document_5423',
#  'document_5720',
#  'document_5720',
#  'document_5720',
#  'document_5720',
#  'document_5722',
#  'document_5722',
#  'document_5728',
#  'document_5728',
#  'document_5777',
#  'document_5777',
#  'document_5777',
#  'document_5777',
#  'document_5777',
#  'document_5777',
#  'document_5818',
#  'document_5818',
#  'document_5832',
#  'document_5923',
#  'document_5936',
#  'document_5936',
#  'document_5936',
#  'document_5952',
#  'document_5952',
#  'document_5967',
#  'document_5967',
#  'document_5967',
#  'document_5967',
#  'document_5996',
#  'document_5996',
#  'document_5996',
#  'document_5996',
#  'document_5996',
#  'document_5999',
#  'document_5999',
#  'document_5999',
#  'document_5999',
#  'document_6240',
#  'document_6240',
#  'document_6298',
#  'document_6298',
#  'document_6298',
#  'document_6479',
#  'document_6514',
#  'document_6516',
#  'document_6516',
#  'document_6531',
#  'document_6531',
#  'document_6539',
#  'document_6539',
#  'document_6539',
#  'document_6539',
#  'document_6654',
#  'document_6789',
#  'document_6789',
#  'document_6789',
#  'document_6789',
#  'document_6789',
#  'document_6826',
#  'document_6826',
#  'document_7041',
#  'document_7041',
#  'document_7145',
#  'document_7158',
#  'document_7158',
#  'document_7163',
#  'document_7185',
#  'document_7241',
#  'document_7241',
#  'document_7241',
#  'document_7243',
#  'document_7243',
#  'document_7243',
#  'document_7243',
#  'document_7243',
#  'document_7353',
#  'document_7353',
#  'document_7384',
#  'document_7384',
#  'document_7402',
#  'document_7402',
#  'document_7407',
#  'document_7407',
#  'document_7407',
#  'document_7409',
#  'document_7483',
#  'document_7483',
#  'document_7483',
#  'document_7483',
#  'document_7486',
#  'document_7486',
#  'document_7535',
#  'document_7535',
#  'document_7576',
#  'document_7576',
#  'document_7599',
#  'document_7599',
#  'document_7599',
#  'document_7698',
#  'document_7698',
#  'document_7698',
#  'document_7716',
#  'document_7716',
#  'document_7741',
#  'document_7744',
#  'document_7744',
#  'document_7744',
#  'document_7744',
#  'document_7840',
#  'document_7840',
#  'document_7840',
#  'document_7843',
#  'document_7845',
#  'document_7845',
#  'document_7845',
#  'document_7884',
#  'document_7885',
#  'document_7952',
#  'document_7957',
#  'document_7957',
#  'document_7990',
#  'document_7990',
#  'document_7990',
#  'document_7993',
#  'document_8070',
#  'document_8070',
#  'document_8070',
#  'document_8116',
#  'document_8116',
#  'document_8125',
#  'document_8125',
#  'document_8174',
#  'document_8174',
#  'document_8174',
#  'document_8183',
#  'document_8202',
#  'document_8202',
#  'document_8202',
#  'document_8202',
#  'document_8246',
#  'document_8246',
#  'document_8292',
#  'document_8300',
#  'document_8308',
#  'document_8386',
#  'document_8386',
#  'document_8386',
#  'document_8475',
#  'document_8475',
#  'document_8483',
#  'document_8589',
#  'document_8589',
#  'document_8589',
#  'document_8591',
#  'document_8591',
#  'document_8591',
#  'document_8655',
#  'document_8787',
#  'document_8787',
#  'document_8787',
#  'document_8815',
#  'document_8853',
#  'document_8853',
#  'document_8918',
#  'document_8918',
#  'document_8941',
#  'document_8955',
#  'document_8977',
#  'document_9005',
#  'document_9008',
#  'document_9070',
#  'document_9070',
#  'document_9134',
#  'document_9156',
#  'document_9205',
#  'document_9253',
#  'document_9295',
#  'document_9325',
#  'document_9343',
#  'document_9343',
#  'document_9413',
#  'document_9453',
#  'document_9488',
#  'document_9488',
#  'document_9521',
#  'document_9528',
#  'document_9528',
#  'document_9528',
#  'document_9586',
#  'document_9664',
#  'document_9679',
#  'document_9706',
#  'document_9757',
#  'document_9775',
#  'document_9782',
#  'document_9782',
#  'document_9782',
#  'document_9783',
#  'document_9783',
#  'document_9798',
#  'document_9798',
#  'document_9980']

# %%
import pandas as pd
d = Vocabulary
#def engine(d):
a = set()
b = []
res = defaultdict(list)
s = input().strip().split()
ps = PorterStemmer()
s = [ps.stem(w) for w in s]
print(s)
if len(s) > 1: 
    a = list(set(d[s[0]]).intersection(*[set(d[s[i]]) for i in range(1,len(s)) if s[i] != 'movies']))
    #return a
else:
    a = list(set(d[s[0]]))
    #return a

for i in range(len(a)):
    b.append(a[i].partition('_')[2])

for j in range(len(b)):
    try:
        with open(r'C:\Users\Notebook HP\HW3\article_{}.tsv'.format(b[j]),'r') as tsv:
            paths = str([line.strip().split('\\t') for line in tsv][0])


        title = paths.split('\\t')[0][2:]
        intro = paths.split('\\t')[1]
        res['Title'].append(title)
        res['Intro'].append(intro)
           
    except Exception as e:
        continue  
r = pd.DataFrame(list(zip(res['Title'], res['Intro'])), columns =['Title', 'Intro'])      
print(r)
# Out:
# 1980
# ['1980']
#                                   Title  \
# 0                  The Psychotronic Man
# 1                   The Toolbox Murders
# 2                         Hero at Large
# 3               The Prowler (1981 film)
# 4                 Scruples (miniseries)
# 5                      Polyester (film)
# 6               The Visitor (1979 film)
# 7               Honeysuckle Rose (film)
# 8         Thank God It\'s Friday (film)
# 9                        The Sea Wolves
# 10                    Stardust Memories
# 11               The Dogs of War (film)
# 12                         Urban Cowboy
# 13                Rough Cut (1980 film)
# 14                      Forbidden World
# 15                     Alligator (film)
# 16               Why Girls Love Sailors
# 17                    Fatso (1980 film)
# 18                     Hopscotch (film)
# 19           The Lathe of Heaven (film)
# 20                        Health (film)
# 21          Treasure Island (1973 film)
# 22          Dressed to Kill (1980 film)
# 23            Mother\'s Day (1980 film)
# 24                   Chapter Two (film)
# 25                  Die Laughing (film)
# 26                        The Earthling
# 27                    Melvin and Howard
# 28          The Man with Bogart\'s Face
# 29                The Hollywood Knights
# ..                                  ...
# 138                       The Stunt Man
# 139             The Elephant Man (film)
# 140                       Ruckus (film)
# 141                The First Deadly Sin
# 142             The Formula (1980 film)
# 143                       Antropophagus
# 144       The Silent Scream (1979 film)
# 145                   Human Experiments
# 146                    Nightwing (film)
# 147                   Simon (1980 film)
# 148          The Final Countdown (film)
# 149         Rock \'n\' Roll High School
# 150                        Dixie (film)
# 151                     September Storm
# 152               Heaven\'s Gate (film)
# 153                  The Shining (film)
# 154                Witches' Brew (film)
# 155                       Xanadu (film)
# 156        Tuck Everlasting (1981 film)
# 157            Somewhere in Time (film)
# 158          Just Tell Me What You Want
# 159                       Dead & Buried
# 160              The Barefoot Executive
# 161                     Tom Horn (film)
# 162  Don\'t Go in the Woods (1981 film)
# 163                   Heart Beat (film)
# 164           Atlantic City (1980 film)
# 165                 Herbie Goes Bananas
# 166                          Motel Hell
# 167                        Animalympics
#
#                                                  Intro
# 0    The Psychotronic Man is a science fiction cult...
# 1    The Toolbox Murders is a 1978 American slasher...
# 2    Hero at Large is a 1980 American comedy film s...
# 3    The Prowler is a 1981 American slasher film di...
# 4    Scruples is a 1980 television mini-series, bas...
# 5
# 6
# 7
# 8
# 9    The Sea Wolves is a 1980 war film starring Gre...
# 10   Stardust Memories is a 1980 American comedy-dr...
# 11
# 12   "Urban Cowboy is a 1980 American romantic dram...
# 13   Rough Cut is a 1980 American heist film writte...
# 14   Forbidden World, originally titled Mutant, is ...
# 15   Alligator is a 1980 American monster movie dir...
# 16   Why Girls Love Sailors is an American comedy s...
# 17   Fatso is a 1980 American comedy film written a...
# 18   Hopscotch is a 1980 American cold war comedy-d...
# 19   The Lathe of Heaven is a 1980 film adaptation ...
# 20   "HealtH (also known as Health[3] and H.E.A.L.T...
# 21   Treasure Island is a 1973 animated feature fil...
# 22
# 23   Mother\'s Day is a 1980 American slasher film ...
# 24   Chapter Two is a 1979 American Metrocolor roma...
# 25   Die Laughing is a 1980 American comedy-drama f...
# 26
# 27   Melvin and Howard (stylized as Melvin (and How...
# 28   The Man with Bogart\'s Face (also called Sam M...
# 29   The Hollywood Knights is a 1980 American teen ...
# ..                                                 ...
# 138  The Stunt Man is a 1980 American action comedy...
# 139
# 140  Ruckus, also known as Ruckus in Madoc County a...
# 141  The First Deadly Sin is a 1980 American crime ...
# 142  The Formula is a 1980 American-West German mys...
# 143
# 144  The Silent Scream (released as Silent Scream)[...
# 145  "Human Experiments (also known as Beyond the G...
# 146  "Nightwing is a 1979 American horror film dire...
# 147  Simon is a 1980 American comedy film. It was w...
# 148  The Final Countdown is a 1980 alternate histor...
# 149  Rock \'n\' Roll High School is a 1979 American...
# 150  "Dixie is a 1943 American biographical film of...
# 151  September Storm is a 1960 American adventure f...
# 152  Heaven\'s Gate is a 1980 American epic Western...
# 153
# 154  Witches' Brew, also known as Which Witch Is Wh...
# 155
# 156  Tuck Everlasting is a 1981 American film based...
# 157  Somewhere in Time is a 1980 American romantic ...
# 158  Just Tell Me What You Want is a 1980 American ...
# 159
# 160  "The Barefoot Executive is a live-action Walt ...
# 161  Tom Horn is a 1980 Western film directed by Wi...
# 162  Don\'t Go in the Woods (also known as Don\'t G...
# 163  Heart Beat is a 1980 American drama film writt...
# 164  Atlantic City (French: Atlantic City, USA) is ...
# 165  Herbie Goes Bananas is a 1980 American comedy ...
# 166  Motel Hell is a 1980 American horror comedy fi...
# 167
#
# [168 rows x 2 columns]
