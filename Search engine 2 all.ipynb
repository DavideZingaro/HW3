# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import os
import csv
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Notebook
# [nltk_data]     HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Notebook
# [nltk_data]     HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from lxml import html
from bs4 import BeautifulSoup
import requests
import urllib.request
import bs4
import csv

# %%
tree = html.parse(r"C:\Users\Notebook HP\Desktop\Homeworks\HW3\movies1.html")
movies2 = html.tostring(tree)
soup = BeautifulSoup(movies2)
links = []
for link in soup.findAll('a'):
    links.append(link.get('href'))

# %%
links[:5]
# Out:
# ['https://en.wikipedia.org/wiki/Love_by_the_Light_of_the_Moon',
#  'https://en.wikipedia.org/wiki/The_Martyred_Presidents',
#  'https://en.wikipedia.org/wiki/Terrible_Teddy,_the_Grizzly_King',
#  'https://en.wikipedia.org/wiki/Jack_and_the_Beanstalk_(1902_film)',
#  'https://en.wikipedia.org/wiki/Alice_in_Wonderland_(1903_film)']

# %%
'Love_by1' in links[0]
# Out:
# True

# %%
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize
import os

# %%
os.chdir('C:\\Users\\Notebook HP\\Desktop\\TSV_files')
Folder=os.listdir()
Vocabulary=defaultdict(list)
#j=9998
for j in range(10000):
    #for elem in Folder:
    name='document_{}'.format(j)
    try:
        document=open(str(r'C:\Users\Notebook HP\Desktop\TSV_files\article_{}.tsv'.format(j)),'r+',encoding='utf-8')
    except Exception as e:
        continue
    words=word_tokenize(document.read())
    words
    for w in words:
        Vocabulary[w].append(name)
    #j = j+1

# %%
Vocabulary['disney']
# Out:
# ['document_1298',
#  'document_1298',
#  'document_1602',
#  'document_1602',
#  'document_1697',
#  'document_1697',
#  'document_2281',
#  'document_2563',
#  'document_2870',
#  'document_2870',
#  'document_2892',
#  'document_2892',
#  'document_2892',
#  'document_3027',
#  'document_3027',
#  'document_3027',
#  'document_3056',
#  'document_3124',
#  'document_3124',
#  'document_3124',
#  'document_3199',
#  'document_3234',
#  'document_3234',
#  'document_3234',
#  'document_3276',
#  'document_3276',
#  'document_3522',
#  'document_3522',
#  'document_3537',
#  'document_3537',
#  'document_3537',
#  'document_3537',
#  'document_3608',
#  'document_3608',
#  'document_3608',
#  'document_3608',
#  'document_3608',
#  'document_3622',
#  'document_3829',
#  'document_3906',
#  'document_3906',
#  'document_3906',
#  'document_3906',
#  'document_4174',
#  'document_4306',
#  'document_4306',
#  'document_4440',
#  'document_4440',
#  'document_4440',
#  'document_4440',
# ...

# %% [markdown]
# # Importante creare il vocabulary prima e i links di wikipedia
# Magari più avanti facciamo la funzione.

# %%
import pandas as pd
d = Vocabulary
#def engine(d):
a = set()
b = []
res = defaultdict(list)
s = input().strip().split()
ps = PorterStemmer()
s = [ps.stem(w) for w in s]
print(s)
if len(s) > 1: 
    a = list(set(d[s[0]]).intersection(*[set(d[s[i]]) for i in range(1,len(s)) if s[i] != 'movies']))
    #return a
else:
    a = list(set(d[s[0]]))
    #return a

for i in range(len(a)):
    b.append(a[i].partition('_')[2])

for j in range(len(b)):
    try:
        with open(r'C:\Users\Notebook HP\HW3\article_{}.tsv'.format(b[j]),'r') as tsv:
            paths = str([line.strip().split('\\t') for line in tsv][0])


        title = paths.split('\\t')[0][2:]
        intro = paths.split('\\t')[1]
        res['Title'].append(title)
        res['Intro'].append(intro)
        
        title = title.replace(" ", "_")
        for i in links:
            if title in i:
                res['Wikipedia Url'].append(i)
        
           
    except Exception as e:
        continue  
r = pd.DataFrame(list(zip(res['Title'], res['Intro'], res['Wikipedia Url'])), columns =['Title', 'Intro', 'Wikipedia Url'])      
print(r)
# Out:
# 1980
# ['1980']
#                                   Title  \
# 0                  The Psychotronic Man
# 1                   The Toolbox Murders
# 2                         Hero at Large
# 3               The Prowler (1981 film)
# 4                 Scruples (miniseries)
# 5                      Polyester (film)
# 6               The Visitor (1979 film)
# 7               Honeysuckle Rose (film)
# 8         Thank God It\'s Friday (film)
# 9                        The Sea Wolves
# 10                    Stardust Memories
# 11               The Dogs of War (film)
# 12                         Urban Cowboy
# 13                Rough Cut (1980 film)
# 14                      Forbidden World
# 15                     Alligator (film)
# 16               Why Girls Love Sailors
# 17                    Fatso (1980 film)
# 18                     Hopscotch (film)
# 19           The Lathe of Heaven (film)
# 20                        Health (film)
# 21          Treasure Island (1973 film)
# ...
